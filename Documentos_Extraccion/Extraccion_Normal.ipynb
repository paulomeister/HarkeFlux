# %%
from google.colab import files
import pandas as pd

#Extraccion dataset delitos informáticos 1
uploaded = files.upload()

file_name = list(uploaded.keys())[0]

df_delitos_informaticos1 = pd.read_csv(file_name)

df_delitos_informaticos1.head()
# Out:
#      <input type="file" id="files-88226907-73f4-4f8b-af98-dfc961d26789" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88226907-73f4-4f8b-af98-dfc961d26789">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Extraccion dataset delitos informáticos 1
uploaded = files.upload()

file_name = list(uploaded.keys())[0]

df_delitos_informaticos2 = pd.read_csv(file_name)
# Out:
#      <input type="file" id="files-7b302ac6-9c23-47b8-96c0-9114307f2262" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b302ac6-9c23-47b8-96c0-9114307f2262">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_delitos_informaticos2.head()
# Out:
#                FECHA HECHO  COD_DEPTO DEPARTAMENTO  COD_MUNI    MUNICIPIO  \
# 0  2006 May 13 12:00:00 AM         11  BOGOTA D.C.     11001  BOGOTA D.C.
# 1  2006 Oct 06 12:00:00 AM         11  BOGOTA D.C.     11001  BOGOTA D.C.
# 2  2008 May 24 12:00:00 AM         11  BOGOTA D.C.     11001  BOGOTA D.C.
# 3  2009 Jan 01 12:00:00 AM         41        HUILA     41001        NEIVA
# 4  2009 Jan 02 12:00:00 AM         11  BOGOTA D.C.     11001  BOGOTA D.C.
#
#                                 DESCRIPCION CONDUCTA  CANTIDAD
# 0  ARTICULO 269I. HURTO POR MEDIOS INFORMATICOS Y...         1
# 1  ARTICULO 269A. ACCESO ABUSIVO A UN SISTEMA INF...         1
# 2  ARTICULO 269A. ACCESO ABUSIVO A UN SISTEMA INF...         1
# 3       ARTICULO 269F. VIOLACION DE DATOS PERSONALES         1
# 4  ARTICULO 269A. ACCESO ABUSIVO A UN SISTEMA INF...         1

# %%
from google.colab import files
import pandas as pd

uploaded = files.upload()

file_name = list(uploaded.keys())[0]

df = pd.read_excel(file_name, header=[7,8])

df.head()
# Out:
#      <input type="file" id="files-ecbff0df-7799-4151-8140-6a75f4c354f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ecbff0df-7799-4151-8140-6a75f4c354f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
